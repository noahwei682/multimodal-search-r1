# %% [markdown]
# ## Train/Val Data Format
#
# The data is stored in Parquet format and should include the following columns:
#
# - `prompt`
# - `images`
# - `reward_model`
# - `data_source:` must include "mmsearch_r1" to enable reward calculation correctly
# - `image_urls:` store the corresponding image URL in string format, which will be used for image search operations. (It can also be in other formats, depending on how your image search tool is implemented.)
# extra_info: (optional)

# %%
import pandas as pd

data = pd.read_parquet('mini_data.pq')
data
# Out:
#                                               prompt  \
# 0  [{'content': 'What is the country of origin of...
# 1  [{'content': 'What is this building dedicated ...
# 2  [{'content': 'Who commissioned this building?'...
# 3  [{'content': 'What is this garden named after?...
# 4  [{'content': 'Who is the owner of this place?'...
#
#                                               images  \
# 0  [{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\...
# 1  [{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\...
# 2  [{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\...
# 3  [{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\...
# 4  [{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\...
#
#                                         reward_model  \
# 0  {'candidate_answers': '["Kingdom of Spain", "E...
# 1  {'candidate_answers': '["Trikay", "Padmayani",...
# 2  {'candidate_answers': '["Order of Saint John o...
# 3  {'candidate_answers': '["Tuileries Palace", "P...
# ...

# %%
data['prompt'][0]
# Out:
# array([{'content': 'What is the country of origin of this food?', 'role': 'user'}],
#       dtype=object)

# %%
data['images'][0]
# Out:
# array([{'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01\x06\x01\x06\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x02\x03\x06\x01\x07\x00\x08\t\xff\xc4\x00B\x10\x00\x02\x02\x01\x03\x02\x04\x04\x03\x07\x03\x04\x01\x04\x00\x07\x01\x02\x03\x04\x11\x00\x05!\x121\x06\x13AQ\x14"aq2\x81\x91\x07\x15#B\xa1\xb1\xc1Rb\xd1$3\xe1\xf0\xf1\x08
# ...

# %%
data['reward_model'][0] # 'candidate_answers' is not necessary
# Out:
# {'candidate_answers': '["Kingdom of Spain", "ESP", "\\ud83c\\uddea\\ud83c\\uddf8", "ES", "Spain"]',
#  'ground_truth': 'Spain',
#  'style': 'rule'}

# %%
data['data_source'][0]
# Out:
# 'mmsearch_r1/infoseek_train_split'

# %%
data['image_urls'][0] # set your image url or other formats
